# %% [markdown]
# <a href="https://colab.research.google.com/github/SaveliiZalavin/OPD_PIK/blob/Analys/analysPIK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from contextlib import redirect_stdout

# %% [markdown]
# Вводим застройщика и класс

# %%
dev = input("Введите название застройщика: ")
cl = input("Введите класс жилья: ")
# Out:
# Введите название застройщика: MR Group
# Введите класс жилья: Элит

# %%
file_name = "analys.xlsx"

# %% [markdown]
# Формируем отчет по классу и застройщику (тенденция)

# %%
df = pd.read_excel(file_name)
ndf = df[((df['Застройщик'] == dev) & (df['Класс'] == cl))]
with open(f"{cl}_{dev}.txt", 'w') as f, redirect_stdout(f):
  print(f"Застройщик: {dev}")
  print(f"Класс: {cl}")
  print(f"Средняя продаваемая площадь жилья: {round(ndf['Продаваемая площадь квартир'].mean())}")
  print(f"Среднее количество квартир: {round(ndf['Количество квартир'].mean())}")
  print(f"Средняя площадь квартир: {round(ndf['Средняя площадь квартиры'].mean())}")
  print(f"Средняя доля студий: {round(ndf['Студии д'].mean(), 2)*100}%")
  print(f"Средняя доля 1кк: {round(ndf['1кк д'].mean(), 2)*100}%")
  print(f"Средняя доля 2кк: {round(ndf['2кк д'].mean(), 2)*100}%")
  print(f"Средняя доля 3кк: {round(ndf['3кк д'].mean(), 2)*100}%")
  print(f"Средняя доля 4кк: {round(ndf['4кк д'].mean(), 2)*100}%")
  print(f"Массинг: {ndf['Массинг'].mode()[0]}")
  print(f"Конструктив здания: {ndf['Конструктив здания'].mode()[0]}")
  print(f"Конструктив фасада: {ndf['Конструктив фасада'].mode()[0]}")
  print(f"Материалы облицовки фасада: {ndf['Материалы облицовки фасада'].mode()[0]}")
  print(f"Подсветка фасада: {ndf['Подсветка фасада'].mode()[0]}")
  print(f"Размещение внешних блоков кондиционеров: {ndf['Размещение внешних блоков кондиционеров'].mode()[0]}")
  print(f"Подготовка под кондиционирование: {ndf['Подготовка под кондиционирование'].mode()[0]}")
  print(f"Материал оконного профиля: {ndf['Материал оконного профиля'].mode()[0]}")
  print(f"Угловые окна: {ndf['Угловые окна'].mode()[0]}")
  print(f"Окна в пол: {ndf['Окна в пол'].mode()[0]}")
  print(f"Панорамные окна: {ndf['Панорамные окна'].mode()[0]}")
  print(f"Моллированные: {ndf['Моллированные'].mode()[0]}")
  print(f"Широкие окна: {ndf['Широкие окна'].mode()[0]}")
  print(f"Наиболее частая ширина типовых окон: {ndf['Наиболее частая ширина типовых окон'].mode()[0]}")
  print(f"Наиболее частая высота типовых окон: {ndf['Наиболее частая высота типовых окон'].mode()[0]}")
  print(f"Наиболее частая высота типовых окон: {ndf['Наиболее частая высота типовых окон'].mode()[0]}")
  print(f"Коэффициент летних помещений: {ndf['Коэффициент летних помещений'].mode()[0]}")
  print(f"Французский балкон: {ndf['Французский балкон'].mode()[0]}")
  print(f"Открытый балкон с металлическими ограждениями: {ndf['Открытый балкон с металлическими ограждениями'].mode()[0]}")
  print(f"Открытый балкон с прозрачными ограждениями: {ndf['Открытый балкон с прозрачными ограждениями'].mode()[0]}")
  print(f"Закрытый балкон: {ndf['Закрытый балкон'].mode()[0]}")
  print(f"Лоджия: {ndf['Лоджия'].mode()[0]}")
  print(f"Терраса на 1 эт (палисадник): {ndf['Терраса на 1 эт (палисадник)'].mode()[0]}")
  print(f"Терраса на среднем/типовом этаже: {ndf['Терраса на среднем/типовом этаже'].mode()[0]}")
  print(f"Терраса на кровле: {ndf['Терраса на кровле'].mode()[0]}")
  print(f"Отделка лобби: {ndf['Отделка лобби'].mode()[0]}")
  print(f"Меблировка лобби: {ndf['Меблировка лобби'].mode()[0]}")
  print(f"Наличие центрального / гранд-лобби: {ndf['Наличие центрального / гранд-лобби'].mode()[0]}")
  print(f"Колясочные: {ndf['Колясочные'].mode()[0]}")
  print(f"Велосипедные: {ndf['Велосипедные'].mode()[0]}")
  print(f"Лапомойки: {ndf['Лапомойки'].mode()[0]}")
  print(f"Зона ожидания: {ndf['Зона ожидания'].mode()[0]}")
  print(f"Стойка Reception: {ndf['Стойка Reception'].mode()[0]}")
  print(f"Гостевой с/у: {ndf['Гостевой с/у'].mode()[0]}")
  print(f"Детская игровая зона: {ndf['Детская игровая зона'].mode()[0]}")
  print(f"Коворкинг: {ndf['Коворкинг'].mode()[0]}")
  print(f"Кофе-поинт: {ndf['Кофе-поинт'].mode()[0]}")
  print(f"Постамат: {ndf['Постамат'].mode()[0]}")
  print(f"Переговорная: {ndf['Переговорная'].mode()[0]}")
  print(f"Отделка типового этажа: {ndf['Отделка типового этажа (описание / концепция): межквартирный холл и лифтовой коридор'].mode()[0]}")
  print(f"Потолок на типовом этаже: {ndf['Потолок на типовом этаже'].mode()[0]}")
  print(f"Входные двери в квартиры: {ndf['Входные двери в квартиры (особенности)'].mode()[0]}")
  print(f"Гостевые С/У: {ndf['Гостевые С/У'].mode()[0]}")
  print(f"Высота первого этажа в чистоте: {ndf['Высота первого этажа в чистоте'].mode()[0]}")
  print(f"Двусветное лобби: {ndf['Двусветное лобби'].mode()[0]}")
  print(f"Кондиционирование в лобби: {ndf['Кондиционирование в лобби'].mode()[0]}")
  print(f"Отделка лифтовой кабины: {ndf['Отделка лифтовой кабины'].mode()[0]}")
  print(f"Кол-во лифтов на 1 подъезд: {ndf['Кол-во лифтов на 1 подъезд'].mode()[0]}")
  print(f"Скорость лифта: {ndf['Скорость лифта'].mode()[0]}")
  print(f"Время ожидания лифта: {ndf['Время ожидания лифта'].mode()[0]}")
  print(f"Автоматический вызов лифтов на первый этаж: {ndf['Автоматический вызов лифтов на первый этаж'].mode()[0]}")
  print(f"Опускание лифта в паркинг: {ndf['Опускание лифта в паркинг'].mode()[0]}")
  print(f"Высота типового этажа пол-пол: {ndf['Высота типового этажа пол-пол'].mode()[0]}")
  print(f"Высота типового этажа пол-потолок: {ndf['Высота типового этажа пол-потолок'].mode()[0]}")
  print(f"Высота верхних этажей пол-пол: {ndf['Высота верхних этажей пол-пол'].mode()[0]}")
  print(f"Высота верхних этажей пол-потолок: {ndf['Высота верхних этажей пол-потолок'].mode()[0]}")
  print(f"Глубина квартир: {ndf['Глубина квартир'].mode()[0]}")
  print(f"Система противопожарной безопасности: {ndf['Система противопожарной безопасности'].mode()[0]}")
  print(f"Тип паркинга : {ndf['Тип паркинга '].mode()[0]}")
  print(f"Среднее Количество м/м: {round(ndf['Количество м/м'].mean())}")
  print(f"Обеспеченность машиноместами: {round(ndf['Обеспеченность машиноместами'].mean(), 2)}")
  print(f"Рампы: {ndf['Рампы'].mode()[0]}")
  print(f"Средняя высота паркинга (пол-потолок): {ndf['Средняя высота паркинга (пол-потолок)'].mode()[0]}")
  print(f"Возможность установки подъемного механизма: {ndf['Возможность установки подъемного механизма'].mode()[0]}")
  print(f"Наличие зарядки для автомобилей на электрическом двигателе: {ndf['Наличие зарядки для автомобилей на электрическом двигателе'].mode()[0]}")
  print(f"Места для велосипедов в паркинге: {ndf['Места для велосипедов в паркинге'].mode()[0]}")
  print(f"Среднее количество кладовых: {round(ndf['количество кладовок'].mean())}")
  print(f"Обеспеченность кладовыми: {round(ndf['Обеспеченность кладовыми'].mean(), 2)}")
  print(f"Продаваемая площадь кладовых: {round(ndf['Продаваемая площадь кладовых'].mean(), 2)}")
  print(f"Средняя площадь кладовых: {round(ndf['Средняя площадь кладовых'].mean(), 2)}")
  print(f"Тип разводки отопления: {ndf['Тип разводки отопления'].mode()[0]}")
  print(f"Тип разводки воды: {ndf['Тип разводки воды'].mode()[0]}")
  print(f"Отделка квартир: {ndf['Отделка квартир '].mode()[0]}")
  print(f"Возможность докупить полную отделку: {ndf['Возможность докупить полную отделку'].mode()[0]}")
  print(f"Шумоизоляция пола: {ndf['Шумоизоляция пола'].mode()[0]}")
  print(f"Мусороудаление: {ndf['Мусороудаление'].mode()[0]}")
  print(f"Бесперебойное горячее водоснабжение/отопление: {ndf['Бесперебойное горячее водоснабжение/отопление'].mode()[0]}")
  print(f"Фильтрация воды: {ndf['Фильтрация воды'].mode()[0]}")
  print(f"Система усиления GSM сигнала (лифты, паркинг и тд): {ndf['Система усиления GSM сигнала (лифты, паркинг и тд)'].mode()[0]}")
  print(f"Вызывная панель / домофон: {ndf['Вызывная панель / домофон'].mode()[0]}")
  print(f"Зона Reception: {ndf['Зона Reception'].mode()[0]}")
  print(f"Помещения ГБР: {ndf['Помещения ГБР'].mode()[0]}")
  print(f"Закрытый двор: {ndf['Закрытый двор'].mode()[0]}")
  print(f"Бесключевой доступ: {ndf['Бесключевой доступ'].mode()[0]}")
  print(f"Площадка для баскетбола: {ndf['Площадка для баскетбола (наличие)'].mode()[0]}")
  print(f"Футбольная площадка: {ndf['Футбольная площадка (наличие)'].mode()[0]}")
  print(f"Столы для настольного тенниса: {ndf['Столы для настольного тенниса  (наличие)'].mode()[0]}")
  print(f"Велодорожки: {ndf['Велодорожки'].mode()[0]}")
  print(f"Пешеходный бульвар: {ndf['Пешеходный бульвар'].mode()[0]}")
  print(f"Благоустроенная набережная: {ndf['Благоустроенная набережная'].mode()[0]}")
  print(f"Тип МАФ: {ndf['Тип МАФ'].mode()[0]}")
  print(f"PlayHub: {ndf['PlayHub'].mode()[0]}")
  print(f"Local Play: {ndf['Local Play'].mode()[0]}")
  print(f"SportHub: {ndf['SportHub'].mode()[0]}")
  print(f"DogHub: {ndf['DogHub (площадка для выгула собак)'].mode()[0]}")
  print(f"Рабочие места во дворе: {ndf['Рабочие места во дворе'].mode()[0]}")
  print(f"WI-FI на территории: {ndf['WI-FI на территории'].mode()[0]}")
  print(f"Эксплуатируемая кровля: {ndf['Эксплуатируемая кровля'].mode()[0]}")
  print(f"Площадь БКФН на 1 этажах: {round(ndf['Площадь БКФН на 1 этажах, кв.м'].mean(), 2)}")
  print(f"Количество БКФН: {round(ndf['Количество БКФН'].mean(), 2)}")
  print(f"Средняя площадь БКФН: {round(ndf['Средняя площадь БКФН'].mean(), 2)}")
  print(f"Доля БКФН в составе ЖК: {round(ndf['Доля БКФН в составе ЖК'].mean(), 2)}")
  print(f"Торговый центр: {ndf['Торговый центр'].mode()[0]}")
  print(f"Бизнес-центр: {ndf['Бизнес-центр'].mode()[0]}")
  print(f"Light-industrial: {ndf['Light-industrial'].mode()[0]}")
